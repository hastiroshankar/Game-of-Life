# %%
import numpy as np
from matplotlib import pyplot as plt
import time
from IPython.display import clear_output
import random

# %%
universe = np.zeros((20,20))
for i in [random.randint(5,15) for _ in range(7)]:
    for j in [random.randint(5,15) for _ in range(7)]:
        universe [i,j] = 1

# %%
plt.imshow(universe, cmap = 'Greys')

# %%
def num_neighbors(cell_ind: tuple, universe: np.array):
    num_neighbors = 0
    L0=universe.shape[0]
    L1=universe.shape[1]
    for i in [-1,0,+1]:
        for j in [-1,0,+1]:
            if (i!=0) or (j!=0):
                if cell_ind[0]+i == L0:
                    i = - cell_ind[0]
                if cell_ind[1]+j == L1:
                    j = - cell_ind[1]   
                if universe [cell_ind[0]+i, cell_ind[1]+j] == 1:
                      num_neighbors += 1
    return num_neighbors

def pass_time(universe):
    num_neighbors_map = np.zeros(universe.shape)
    
    for i in range (universe.shape[0]):
        for j in range (universe.shape[1]):
            num_neighbors_map [i,j] = num_neighbors((i,j), universe)
      
    new_universe = np.zeros(universe.shape)
    survivors = (universe == 1) & ((num_neighbors_map == 2) | (num_neighbors_map == 3))
    zombie = (universe == 0) & (num_neighbors_map == 3)
    new_universe = (survivors == 1) | (zombie == 1)
    return new_universe

# %%
num_turns = 50
new_universe = universe
for _ in range (num_turns):
    new_universe = pass_time(new_universe)
    plt.imshow(new_universe, cmap = 'Greys')
    plt.figure(figsize=(10,10))
    plt.show()
